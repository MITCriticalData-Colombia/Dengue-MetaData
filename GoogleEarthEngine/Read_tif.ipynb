# %%
from skimage import io

# %%
im = io.imread('Images/Image 2013_6_sharpend.tiff')
im.shape
# Out:
# (1664, 2757, 3)

# %%
from matplotlib import pyplot as plt
plt.imshow(im, interpolation='nearest')
plt.show()
