# %%
# !python multi_var_time_series/encoder.py
# Out:
# 2021-08-27 14:32:45.504447: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-08-27 14:32:45.504475: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/sebasmos/Desktop/Dengue-MetaData/multi_var_time_series/encoder.py:29: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   merge_cases_temp_precip = merge_cases_temp_precip.drop('Unnamed: 0', 1)
# (561, 3)
# (63, 3)
# trainX shape == (547, 14, 3).
# trainY shape == (547, 1).
# testX shape == (49, 14, 3).
# testY shape == (49, 1).
# ...

# %%
# !python multi_var_time_series/lstm2d_multi.py
# Out:
# 2021-08-27 14:33:33.773243: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-08-27 14:33:33.773379: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/sebasmos/Desktop/Dengue-MetaData/multi_var_time_series/lstm2d_multi.py:29: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   merge_cases_temp_precip = merge_cases_temp_precip.drop('Unnamed: 0', 1)
# (561, 3)
# (63, 3)
# trainX shape == (547, 14, 3).
# trainY shape == (547, 1).
# testX shape == (49, 14, 3).
# testY shape == (49, 1).
# ...

# %%
# !python multi_var_time_series/lstm_multivariate_dengue_1.py
# Out:
# 2021-08-27 14:34:12.251990: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-08-27 14:34:12.252012: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/sebasmos/Desktop/Dengue-MetaData/multi_var_time_series/lstm_multivariate_dengue_1.py:29: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   merge_cases_temp_precip = merge_cases_temp_precip.drop('Unnamed: 0', 1)
# (561, 3)
# (63, 3)
# trainX shape == (547, 14, 3).
# trainY shape == (547, 1).
# testX shape == (49, 14, 3).
# testY shape == (49, 1).
# ...
